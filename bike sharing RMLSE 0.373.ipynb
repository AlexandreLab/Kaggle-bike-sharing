# %% [markdown]
# # Linear regression
#
# Created 48x12x2 features, 1 feature for each hour, each state of workingday (0 or 1), each month and each year.
# Clean the data by removing data in the which are over the 95% quantile or under the 5%
# fit the linear regression on the clean data

# %%
import pandas as pd
import numpy as np

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81          0       3          13     16
# 1        80          0       8          32     40
# 2        80          0       5          27     32
# 3        75          0       3          10     13
# 4        75          0       0           1      1

# %%
predictors = ['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'hour']
targets = ["count"]
train.columns
train.shape
# train.describe()
# Out:
# (10886, 12)

# %%
def splitDatetime(data, columndate) :
    datatime= pd.to_datetime(data[columndate])
    data['year'] = datatime.dt.year
    data['month'] = datatime.dt.month
    data['day'] = datatime.dt.day
    data['dayoftheweek'] = datatime.dt.dayofweek
    data['hour'] = datatime.dt.hour
    return data

def harmonize(data):
    data.loc[:,['temp', 'atemp', 'windspeed']]= data.loc[:,['temp', 'atemp', 'windspeed']].round(2)
    return

def normalizedata(data):
    for col in predictors:
        try:
            if data.loc[:, col].mean()>3:
                print(data.loc[:, col].max(), col)
                data.loc[:, col]=(data.loc[:, col]-data.loc[:, col].mean())/data.loc[:, col].std()
        except:
            pass


def RMSLE(predictions, targets):
    return np.sqrt(1/len(predictions)*sum(np.square(np.log(predictions+1)-(np.log(targets+1)))))
    

# train["humspeed"] = train["windspeed"]+train["humidity"]
# normalizedata(train)
# harmonize(train)
splitDatetime(train, "datetime")

def createtimefeatures(data):
    for y in range(2011, 2013, 1):
        for m in range(1, 13, 1):
            for x in range(0, 24, 1):
            #     print(quantileup, quantilelow)
                data['hour '+str(x)+str(m)+str(y)] = 0
                data['hour w'+str(x)+str(m)+str(y)] = 0
                data.loc[(data['month']==m) &(data['year']==y) & (data['hour']==x) & (data['workingday']==0), 'hour '+str(x)+str(m)+str(y)] = 1 
                data.loc[(data['month']==m) &(data['year']==y) & (data['hour']==x) & (data['workingday']==1), 'hour w'+str(x)+str(m)+str(y)] = 1

def reduce(data, column):
    frames = []
    for x in range(0, 24, 1):
        quantileup = data.loc[(data['hour']==x),  column].quantile(0.05)
        quantilelow = data.loc[(data['hour']==x),  column].quantile(0.95)
        frames.append(data.loc[(data['hour']==x) & (data[ column]>quantileup) & (data[ column]<quantilelow), :])
    return pd.concat(frames)
    

createtimefeatures(train)    
# result=train
result = reduce(train, "count")
# result = reduce(result, "registered")


# hourlist = [col for col in train.columns if "hour" in col]
# for col in hourlist:
#     print(col)
#     train.loc[train[col]==1, col]= 
# normalizedata(test)
# harmonize(test)
splitDatetime(test, "datetime")
createtimefeatures(test)
print("end")
# train.describe()
# train.corr(method="kendall")
# Out:
# end

# %%
from sklearn import datasets
from sklearn.feature_selection import SelectPercentile, f_classif

predictors = ['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'hour', 'month', 'year']

selector = SelectPercentile(f_classif, percentile=10)
selector.fit(train[predictors], train[targets])

scores = -np.log10(selector.pvalues_)
print(scores)
# Out:
# [  1.98657098e+01   2.91368489e-04   5.27969361e+00   3.64294187e-01
#    2.46322575e+02   2.38506595e+02   1.23861391e+02   5.80584662e+00
#               inf   1.78985256e+01   4.24098223e+01]
# C:\Users\GJ5356\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\utils\validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Linear regression

# %%
print(train.columns)
for col in train.columns:
    print("'"+col+"',", end= " ")
predictors = ['hour 012011', 'hour w012011', 'hour 112011', 'hour w112011', 'hour 212011', 'hour w212011', 'hour 312011', 'hour w312011', 'hour 412011', 'hour w412011', 'hour 512011', 'hour w512011', 'hour 612011', 'hour w612011', 'hour 712011', 'hour w712011', 'hour 812011', 'hour w812011', 'hour 912011', 'hour w912011', 'hour 1012011', 'hour w1012011', 'hour 1112011', 'hour w1112011', 'hour 1212011', 'hour w1212011', 'hour 1312011', 'hour w1312011', 'hour 1412011', 'hour w1412011', 'hour 1512011', 'hour w1512011', 'hour 1612011', 'hour w1612011', 'hour 1712011', 'hour w1712011', 'hour 1812011', 'hour w1812011', 'hour 1912011', 'hour w1912011', 'hour 2012011', 'hour w2012011', 'hour 2112011', 'hour w2112011', 'hour 2212011', 'hour w2212011', 'hour 2312011', 'hour w2312011', 'hour 022011', 'hour w022011', 'hour 122011', 'hour w122011', 'hour 222011', 'hour w222011', 'hour 322011', 'hour w322011', 'hour 422011', 'hour w422011', 'hour 522011', 'hour w522011', 'hour 622011', 'hour w622011', 'hour 722011', 'hour w722011', 'hour 822011', 'hour w822011', 'hour 922011', 'hour w922011', 'hour 1022011', 'hour w1022011', 'hour 1122011', 'hour w1122011', 'hour 1222011', 'hour w1222011', 'hour 1322011', 'hour w1322011', 'hour 1422011', 'hour w1422011', 'hour 1522011', 'hour w1522011', 'hour 1622011', 'hour w1622011', 'hour 1722011', 'hour w1722011', 'hour 1822011', 'hour w1822011', 'hour 1922011', 'hour w1922011', 'hour 2022011', 'hour w2022011', 'hour 2122011', 'hour w2122011', 'hour 2222011', 'hour w2222011', 'hour 2322011', 'hour w2322011', 'hour 032011', 'hour w032011', 'hour 132011', 'hour w132011', 'hour 232011', 'hour w232011', 'hour 332011', 'hour w332011', 'hour 432011', 'hour w432011', 'hour 532011', 'hour w532011', 'hour 632011', 'hour w632011', 'hour 732011', 'hour w732011', 'hour 832011', 'hour w832011', 'hour 932011', 'hour w932011', 'hour 1032011', 'hour w1032011', 'hour 1132011', 'hour w1132011', 'hour 1232011', 'hour w1232011', 'hour 1332011', 'hour w1332011', 'hour 1432011', 'hour w1432011', 'hour 1532011', 'hour w1532011', 'hour 1632011', 'hour w1632011', 'hour 1732011', 'hour w1732011', 'hour 1832011', 'hour w1832011', 'hour 1932011', 'hour w1932011', 'hour 2032011', 'hour w2032011', 'hour 2132011', 'hour w2132011', 'hour 2232011', 'hour w2232011', 'hour 2332011', 'hour w2332011', 'hour 042011', 'hour w042011', 'hour 142011', 'hour w142011', 'hour 242011', 'hour w242011', 'hour 342011', 'hour w342011', 'hour 442011', 'hour w442011', 'hour 542011', 'hour w542011', 'hour 642011', 'hour w642011', 'hour 742011', 'hour w742011', 'hour 842011', 'hour w842011', 'hour 942011', 'hour w942011', 'hour 1042011', 'hour w1042011', 'hour 1142011', 'hour w1142011', 'hour 1242011', 'hour w1242011', 'hour 1342011', 'hour w1342011', 'hour 1442011', 'hour w1442011', 'hour 1542011', 'hour w1542011', 'hour 1642011', 'hour w1642011', 'hour 1742011', 'hour w1742011', 'hour 1842011', 'hour w1842011', 'hour 1942011', 'hour w1942011', 'hour 2042011', 'hour w2042011', 'hour 2
hour w1882011', 'hour 1982011', 'hour w1982011', 'hour 2082011', 'hour w2082011', 'hour 2182011', 'hour w2182011', 'hour 2282011', 'hour w2282011', 'hour 2382011', 'hour w2382011', 'hour 092011', 'hour w092011', 'hour 192011', 'hour w192011', 'hour 292011', 'hour w292011', 'hour 392011', 'hour w392011', 'hour 492011', 'hour w492011', 'hour 592011', 'hour w592011', 'hour 692011', 'hour w692011', 'hour 792011', 'hour w792011', 'hour 892011', 'hour w892011', 'hour 992011', 'hour w992011', 'hour 1092011', 'hour w1092011', 'hour 1192011', 'hour w1192011', 'hour 1292011', 'hour w1292011', 'hour 1392011', 'hour w1392011', 'hour 1492011', 'hour w1492011', 'hour 1592011', 'hour w1592011', 'hour 1692011', 'hour w1692011', 'hour 1792011', 'hour w1792011', 'hour 1892011', 'hour w1892011', 'hour 1992011', 'hour w1992011', 'hour 2092011', 'hour w2092011', 'hour 2192011', 'hour w2192011', 'hour 2292011', 'hour w2292011', 'hour 2392011', 'hour w2392011', 'hour 0102011', 'hour w0102011', 'hour 1102011', 'hour w1102011', 'hour 2102011', 'hour w2102011', 'hour 3102011', 'hour w3102011', 'hour 4102011', 'hour w4102011', 'hour 5102011', 'hour w5102011', 'hour 6102011', 'hour w6102011', 'hour 7102011', 'hour w7102011', 'hour 8102011', 'hour w8102011', 'hour 9102011', 'hour w9102011', 'hour 10102011', 'hour w10102011', 'hour 11102011', 'hour w11102011', 'hour 12102011', 'hour w12102011', 'hour 13102011', 'hour w13102011', 'hour 14102011', 'hour w14102011', 'hour 15102011', 'hour w15102011', 'hour 16102011', 'hour w16102011', 'hour 17102011', 'hour w17102011', 'hour 18102011', 'hour w18102011', 'hour 19102011', 'hour w19102011', 'hour 20102011', 'hour w20102011', 'hour 21102011', 'hour w21102011', 'hour 22102011', 'hour w22102011', 'hour 23102011', 'hour w23102011', 'hour 0112011', 'hour w0112011', 'hour 3112011', 'hour w3112011', 'hour 4112011', 'hour w4112011', 'hour 5112011', 'hour w5112011', 'hour 6112011', 'hour w6112011', 'hour 7112011', 'hour w7112011', 'hour 8112011', 'hour w8112011', 'hour 9112011', 'hour w9112011', 'hour 10112011', 'hour w10112011', 'hour 11112011', 'hour w11112011', 'hour 12112011', 'hour w12112011', 'hour 13112011', 'hour w13112011', 'hour 14112011', 'hour w14112011', 'hour 15112011', 'hour w15112011', 'hour 16112011', 'hour w16112011', 'hour 17112011', 'hour w17112011', 'hour 18112011', 'hour w18112011', 'hour 19112011', 'hour w19112011', 'hour 20112011', 'hour w20112011', 'hour 21112011', 'hour w21112011', 'hour 22112011', 'hour w22112011', 'hour 23112011', 'hour w23112011', 'hour 0122011', 'hour w0122011', 'hour 3122011', 'hour w3122011', 'hour 4122011', 'hour w4122011', 'hour 5122011', 'hour w5122011', 'hour 6122011', 'hour w6122011', 'hour 7122011', 'hour w7122011', 'hour 8122011', 'hour w8122011', 'hour 9122011', 'hour w9122011', 'hour 10122011', 'hour w10122011', 'hour 11122011', 'hour w11122011', 'hour 12122011', 'hour w12122011', 'hour 13122011', 'hour w13122011', 'hour 14122011', 'hour w14122011', 'hour 15122011', 'hour w15122011', 'hour 16122011', '
hour 9122012', 'hour w9122012', 'hour 10122012', 'hour w10122012', 'hour 11122012', 'hour w11122012', 'hour 12122012', 'hour w12122012', 'hour 13122012', 'hour w13122012', 'hour 14122012', 'hour w14122012', 'hour 15122012', 'hour w15122012', 'hour 16122012', 'hour w16122012', 'hour 17122012', 'hour w17122012', 'hour 18122012', 'hour w18122012', 'hour 19122012', 'hour w19122012', 'hour 20122012', 'hour w20122012', 'hour 21122012', 'hour w21122012', 'hour 22122012', 'hour w22122012', 'hour 23122012', 'hour w23122012',]  
    
targets = ["count"]
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual',
#        ...
#        'hour w19122012', 'hour 20122012', 'hour w20122012', 'hour 21122012',
#        'hour w21122012', 'hour 22122012', 'hour w22122012', 'hour 23122012',
#        'hour w23122012', 'predict'],
#       dtype='object', length=1154)
# ...

# %%
from sklearn.cross_validation import KFold
from sklearn.linear_model import LinearRegression, RANSACRegressor
import numpy as np
from sklearn import cross_validation

# Initialize our algorithm class

# Initialize our algorithm class
# alg = RANSACRegressor(LinearRegression())
alg = LinearRegression()

alg.fit(train[predictors],  train[targets])
predictions = alg.predict(train[predictors])

print(predictions)
predictions[predictions<0]=0
# predictions = np.sum(predictions, axis=1)
predictions = np.concatenate(predictions, axis=0)
print(len(predictions))


train['predict']=predictions

print(alg.coef_)
print(RMSLE(train['predict'],train['count']))
train.to_csv("temp.csv")
# Out:
# [[  23.85714286]
#  [  20.57142857]
#  [  14.85714286]
#  ...,
#  [ 196.61538462]
#  [ 129.46153846]
#  [  91.07692308]]
# 10886
# [[-68.65279092 -84.14629741 -71.9385052  ...,  36.95160469  -2.17660044
#    -1.4330107 ]]
# 0.373656648019
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-8-3bba9c3f4833> in <module>()
#      24 print(alg.coef_)
#      25 print(RMSLE(train['predict'],train['count']))
# ---> 26 train.to_csv("temp.csv")
#
# C:\Users\GJ5356\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal, **kwds)
#    1330                                      escapechar=escapechar,
# ...

# %%
predictions = alg.predict(test[predictors])
test['predict']=predictions
submission = test[['datetime', 'predict']]
submission.columns=['datetime', 'count']
submission.to_csv("submission.csv", index=False)

# print(test['datetime'])

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.charts import Scatter
from bokeh.palettes import Spectral4, Spectral6, Spectral8, Spectral11 #color palette

year = 2011
month = 2

output_notebook()

color_coding = Spectral11

plot2 = figure(width=1000, height=600)
plot2.background_fill_color = "whitesmoke"

#Plot the original load curves of each sites
plot2.xaxis.axis_label= 'hour 0'
plot2.yaxis.axis_label='Count'

test= train.loc[train['hour w19122012'], :].copy()
# xaxis= [0.999999999, 1]
# yaxis = [alg.intercept_[0]+ (-alg.intercept_[0])/alg.coef_.flatten()[0]*alg.coef_.flatten()[0], alg.intercept_[0]+ 1*alg.coef_.flatten()[0]]
# plot2.line(train.loc[:, 'count'], train.loc[:, 'hour 0'] , line_color='blue', line_width=1)
print(test.shape)
p = Scatter(test, x='atemp', y='count')
# plot2.circle(train['hour 0'], train['count'], size = 12, color='blue')
# plot2.line(xaxis, yaxis, line_color='red')
# show(plot2)
show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f0e32667-de84-4ff1-8f05-d6f498b65c16">Loading BokehJS ...</span>
#     </div>
# (10886, 1153)
#     <div class="plotdiv" id="89eba224-a5f0-4c57-a02c-43b74231e1fb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
# ...
